# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install hub

# %%
import hub 
import matplotlib.pyplot as plt
import numpy as np
ds = hub.load("hub://activeloop/places205")
# Out:
# hub://activeloop/places205 loaded successfully.
# This dataset can be visualized in Jupyter Notebook by ds.visualize() or at https://app.activeloop.ai/activeloop/places205

# %%
ds
# Out:
# Dataset(path='hub://activeloop/places205', read_only=True, tensors=['images', 'labels'])

# %%
ds.images[1]
# Out:
# Tensor(key='images', index=Index([1]))

# %%
ds.labels[0].data()
# Out:
# {'value': array([0], dtype=uint32), 'text': ['abbey']}

# %%
import matplotlib.pyplot as plt
import numpy as np
im = np.squeeze(ds.images[2])
plt.imshow(im, cmap='gray')

# %%
ds.images[1].shape
# Out:
# (256, 256, 1)

# %%
import tensorflow as tf

# %%
a = tf.image.resize(ds.images[1], [64,64])

# %%
a.shape
# Out:
# TensorShape([64, 64, 1])

# %%
im_a = np.squeeze(a)
plt.imshow(im_a, cmap='gray')

# %%
from PIL import Image
img_aa = Image.fromarray(im_a)
img_aa=img_aa.convert("L")

# %%
img_aa.save("filename.jpeg")

# %% [markdown]
# #Xử lý rõ

# %%
# !pip install hub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install --upgrade tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import hub 
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import torch
ds = torch.hub.load("hub://activeloop/places205")
# dataloader = ds.pytorch(num_workers = 2, shuffle = True, batch_size= 6)
# ds_tensorflow = ds.tensorflow()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-91b09be8dfdd> in <module>
#       4 import tensorflow as tf
#       5 import torch
# ----> 6 ds = torch.hub.load("hub://activeloop/places205")
#       7 # dataloader = ds.pytorch(num_workers = 2, shuffle = True, batch_size= 6)
#       8 # ds_tensorflow = ds.tensorflow()
#
# TypeError: load() missing 1 required positional argument: 'model'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-cf3dcfc2cf3d> in <module>
# ----> 1 img = cv2.imread(ds)
#
# TypeError: Can't convert object to 'str' for 'filename'

# %%
def resize_data(images):
  size = (64,64)
  return tf.image.resize(images, size)

# %%
ds['images'][0]
# Out:
# Tensor(key='images', index=Index([0]))

# %%
ds['images'][0] = tf.image.resize(ds['images'][0], (64,64))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-e9718fa65e01> in <module>
# ----> 1 ds['images'][0] = tf.image.resize(ds['images'][0], (64,64))
#
# /usr/local/lib/python3.7/dist-packages/hub/core/tensor.py in __setitem__(self, item, value)
#     646             self.index[item_index],
#     647             value,
# --> 648             link_callback=update_link_callback,
#     649         )
#     650
#
# /usr/local/lib/python3.7/dist-packages/hub/core/chunk_engine.py in update(self, index, samples, operator, link_callback)
#     983             samples,
#     984             operator,
# --> 985             link_callback=link_callback,
#     986         )
#     987
#
# /usr/local/lib/python3.7/dist-packages/hub/core/chunk_engine.py in _update(self, index, samples, operator, update_commit_diff, link_callback)
#    1220
# ...
